# %%
import os # REMOVE KITWE STUDENTS
import re
from openpyxl import load_workbook

ROOT_FOLDER = r"interal sheel dec 2025"

# Regex for exactly 11 digits
pattern = re.compile(r"^\d{11}$")

for root, dirs, files in os.walk(ROOT_FOLDER):
    for file in files:
        if file.lower().endswith(".xlsx"):
            file_path = os.path.join(root, file)

            try:
                wb = load_workbook(file_path)
                
                for sheet in wb.worksheets:
                    rows_to_delete = []

                    # Start from row 1 (includes header if any)
                    for row in range(1, sheet.max_row + 1):
                        cell_value = sheet[f"B{row}"].value

                        if cell_value is None:
                            continue

                        # Convert to string safely
                        value_str = str(cell_value).strip()

                        if pattern.match(value_str):
                            # Check 9th character (index 8)
                            if value_str[8] == "7":
                                rows_to_delete.append(row)
                            
                    # Delete from bottom to top (very important)
                    for row in reversed(rows_to_delete):
                        sheet.delete_rows(row, 1)

                wb.save(file_path)
                print(f"Processed: {file_path}")

            except Exception as e:
                print(f"Error in file {file_path}: {e}")
# Out:
# Processed: interal sheel dec 2025\SEM II BACHELORS-DEC'2025\B.Com.xlsx
# Processed: interal sheel dec 2025\SEM II BACHELORS-DEC'2025\B.SC Maths -Bio.xlsx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 16
#      13 file_path = os.path.join(root, file)
#      15 try:
# ---> 16     wb = load_workbook(file_path)
#      18     for sheet in wb.worksheets:
#      19         rows_to_delete = []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\reader\excel.py:346, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     316 """Open the given filename and return the workbook
#     317
#     318 :param filename: the path to open or a file-like object
#    (...)
#     342
#     343 """
#     344 reader = ExcelReader(filename, read_only, keep_vba,
#     345                      data_only, keep_links, rich_text)
# ...

# %%
import os
import pandas as pd
import openpyxl
from copy import copy

# ================= CONFIGURATION =================
# Update these paths
MAIN_FOLDER_PATH = r"interal sheel dec 2025"
IMPACT_FILE_PATH = r"IMPACT INTERNAL FILE.xlsx"
# =================================================

def find_file_path(root_folder, target_filename):
    target_str = str(target_filename).lower().strip()
    for root, dirs, files in os.walk(root_folder):
        for file in files:
            if file.endswith((".xlsx", ".xls")):
                name_no_ext = os.path.splitext(file)[0].lower().strip()
                if name_no_ext == target_str:
                    return os.path.join(root, file)
    return None

def process_files():
    print("--- Starting Process (Appending New Row to Bottom) ---")
    
    try:
        # Load Master List (A=Student No, B=Name, C=File Name)
        df_master = pd.read_excel(IMPACT_FILE_PATH, header=0)
    except Exception as e:
        print(f"Error reading Impact Internal File: {e}")
        return

    for index, row in df_master.iterrows():
        student_no = row.iloc[0]
        student_name = row.iloc[1]
        target_file_name = row.iloc[2]
        
        if pd.isna(target_file_name):
            continue

        print(f"Processing File ID: {target_file_name}...")
        found_path = find_file_path(MAIN_FOLDER_PATH, target_file_name)

        if found_path:
            try:
                wb = openpyxl.load_workbook(found_path)
                
                # Loop through ALL sheets
                for sheet_name in wb.sheetnames:
                    ws = wb[sheet_name]
                    
                    # 1. Identify the last row with data
                    last_row = ws.max_row
                    new_row = last_row + 1
                    
                    # 2. Insert Student Data into Col B (2) and C (3) of the NEW row
                    ws.cell(row=new_row, column=2).value = student_no
                    ws.cell(row=new_row, column=3).value = student_name
                    
                    # 3. "Drag" the other information
                    # We look at the row above (last_row). If it has data in other columns, copy it down.
                    if last_row > 0:
                        for col in range(1, ws.max_column + 1):
                            # Skip Column B (2) and C (3) as we just filled them
                            if col in [2, 3]:
                                continue
                            
                            # Get source cell (row above)
                            source_cell = ws.cell(row=last_row, column=col)
                            # Get target cell (new row)
                            target_cell = ws.cell(row=new_row, column=col)
                            
                            # Copy value
                            target_cell.value = source_cell.value
                            
                            # Optional: Copy number format (helps keep dates/currencies correct)
                            if source_cell.has_style:
                                target_cell.number_format = source_cell.number_format

                wb.save(found_path)
                print(f" -> Appended data to ALL sheets in: {found_path}")
                
            except Exception as e:
                print(f" -> Error editing file {found_path}: {e}")
        else:
            print(f" -> File '{target_file_name}' NOT FOUND.")

    print("--- Task Completed ---")

if __name__ == "__main__":
    process_files()
# Out:
# --- Starting Process (Appending New Row to Bottom) ---
# Processing File ID: 17.FOOD & NUT...
#  -> Appended data to ALL sheets in: interal sheel dec 2025\Sem VI-DEC'2025\17.FOOD & NUT.xlsx
# Processing File ID: 16.BPA...
#  -> Appended data to ALL sheets in: interal sheel dec 2025\Sem VI-DEC'2025\16.BPA.xlsx
# --- Task Completed ---

# %%
                            if value_str[8] == "0":
                                rows_to_delete.append(row)
                            if value_str[8] == "1":
                                rows_to_delete.append(row)
                            if value_str[8] == "2":
                                rows_to_delete.append(row)
                            if value_str[8] == "3":
                                rows_to_delete.append(row)
                            if value_str[8] == "5":
                                rows_to_delete.append(row)
                            if value_str[8] == "6":
                                rows_to_delete.append(row)
                            if value_str[8] == "7":
                                rows_to_delete.append(row)
                            if value_str[8] == "8":
                                rows_to_delete.append(row)
                            if value_str[8] == "9":
                                rows_to_delete.append(row)

# %%
import os # REMOVE KITWE STUDENTS
import re
from openpyxl import load_workbook

ROOT_FOLDER = r"interal sheel dec 2025"

# Regex for exactly 11 digits
pattern = re.compile(r"^\d{11}$")

for root, dirs, files in os.walk(ROOT_FOLDER):
    for file in files:
        if file.lower().endswith(".xlsx"):
            file_path = os.path.join(root, file)

            try:
                wb = load_workbook(file_path)
                
                for sheet in wb.worksheets:
                    rows_to_delete = []

                    # Start from row 1 (includes header if any)
                    for row in range(1, sheet.max_row + 1):
                        cell_value = sheet[f"B{row}"].value

                        if cell_value is None:
                            continue

                        # Convert to string safely
                        value_str = str(cell_value).strip()

                        if pattern.match(value_str):
                            # Check 9th character (index 8)
                            if value_str[8] == "0":
                                rows_to_delete.append(row)
                            if value_str[8] == "1":
                                rows_to_delete.append(row)
                            if value_str[8] == "2":
                                rows_to_delete.append(row)
                            if value_str[8] == "3":
                                rows_to_delete.append(row)
                            if value_str[8] == "5":
                                rows_to_delete.append(row)
                            if value_str[8] == "6":
                                rows_to_delete.append(row)
                            if value_str[8] == "7":
                                rows_to_delete.append(row)
                            if value_str[8] == "8":
                                rows_to_delete.append(row)
                            if value_str[8] == "9":
                                rows_to_delete.append(row)
                            
                    # Delete from bottom to top (very important)
                    for row in reversed(rows_to_delete):
                        sheet.delete_rows(row, 1)

                wb.save(file_path)
                print(f"Processed: {file_path}")

            except Exception as e:
                print(f"Error in file {file_path}: {e}")
# Out:
# Processed: interal sheel dec 2025\BACHELOR I\1.Bsc Primary.xlsx
# Processed: interal sheel dec 2025\BACHELOR I\2.ECE.xlsx
# Processed: interal sheel dec 2025\BACHELOR I\5.BA (Civ Rel).xlsx
# Processed: interal sheel dec 2025\BACHELOR I\9.BPA.xlsx
# Processed: interal sheel dec 2025\BACHELOR I\CIVIC RELIGIOUS.xlsx
# Processed: interal sheel dec 2025\masters I\1.M.ed Admin.xlsx
# Processed: interal sheel dec 2025\masters I\10.MBA.xlsx
# Processed: interal sheel dec 2025\masters I\2.M.ed Maths.xlsx
# Processed: interal sheel dec 2025\masters I\4.M.ed Biology.xlsx
# Processed: interal sheel dec 2025\masters I\6.M.ED CIVIC.xlsx
# Processed: interal sheel dec 2025\masters I\7.M.Ed Primary.xlsx
# Processed: interal sheel dec 2025\masters I\8.M.A Lignguistics.xlsx
# Processed: interal sheel dec 2025\masters I\9.MSC Com Sci.xlsx
# Processed: interal sheel dec 2025\masters I\M.ED CHEMISTRY.xlsx
# Processed: interal sheel dec 2025\masters I\MSW.xlsx
# ...
