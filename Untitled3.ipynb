# %%
import os

network = "192.168.1."

for i in range(1, 255):
    ip = network + str(i)
    response = os.system(f"ping -n 1 -w 100 {ip} > nul")  # Windows

    if response == 0:
        print(f"{ip} is up")
# Out:
# 192.168.1.5 is up
# 192.168.1.6 is up

# %%
import socket
print("congrats")
# Out:
# congrats

# %%
import requests

ip = requests.get("https://www.dmiseu.edu.zm").text
print("Public IP:", ip)
# Out:
# Public IP: <!DOCTYPE html>
#
# <html lang="en">
# 	<head>
#
# <meta charset="UTF-8">
#
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
# <title>Best University Zambia | DMI-St. Eugene University</title>
# <meta name="title" content="Best University Zambia | DMI-St. Eugene University"/>
# <meta name="description" content="DMI-St. Eugene University is the best University Zambia and a leading Zambia institutions of higher education offering accredited programs and online learning."/>
# <meta name="keywords" content="Best University Zambia, Zambia Institutions of Higher Education, Top Universities in Zambia, Accredited University Zambia" />
#
# <meta name="robots" content="index, follow">
# <meta name='copyright' content="https://www.dmiseu.edu.zm/"/>
# <meta name='owner' content="https://www.dmiseu.edu.zm/"/>
# <meta name="author" content="https://www.dmiseu.edu.zm/"/>
# <meta name="rating" content="general">
# <meta name="country" content="Zambia"/>
# ...
