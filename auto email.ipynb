# %%
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# === CONFIGURATION ===
file_a = r"C:\Users\USER\Documents\A.xlsx"   # File A: contains student_no, email
file_b = r"C:\Users\USER\Documents\B.xlsx"    # File B: contains student_no, result
email_col = "email"        # Column name for email in File A
student_col = "student_no" # Common column between both files
result_col = "result"      # Column name for result in File B

# Your email settings
smtp_server = "smtp.gmail.com"
smtp_port = 587
your_email = "arockiaajeanconstan@gmail.com"
your_password = "txmv vwnq efyu zpyn"  # Use app password, not real Gmail password

# === READ EXCEL FILES ===
df_a = pd.read_excel(file_a)
df_b = pd.read_excel(file_b)

# Merge data on student number
df = pd.merge(df_a, df_b, on=student_col, how="inner")

# === SEND EMAILS ===
server = smtplib.SMTP(smtp_server, smtp_port)
server.starttls()
server.login(your_email, your_password)

for index, row in df.iterrows():
    student_no = row[student_col]
    email = row[email_col]
    result = row[result_col]

    subject = f"Your Exam Result - {student_no}"
    body = f"""
    Dear Student {student_no},

    The formate is: MODULE CODE / CA / SE / TOTAL / GRADE
    IF THE GRADE IS "F" THEN ITS FAIL.
    
    Your result is: {result}
    # THIS IS A COMPUTER GENERATED MAIL. PLEASE DON'T REPLY.
    """

    # Create email
    msg = MIMEMultipart()
    msg["From"] = your_email
    msg["To"] = email
    msg["Subject"] = subject
    msg.attach(MIMEText(body, "plain"))

    try:
        server.sendmail(your_email, email, msg.as_string())
        print(f"✅ Sent result to {student_no} ({email})")
    except Exception as e:
        print(f"❌ Failed to send to {student_no} ({email}): {e}")

server.quit()
# Out:
# ✅ Sent result to 123 (ajincandy5@gmail.com)
# ✅ Sent result to 124 (arockiaajeanconstan@gmail.com)
# (221,
#  b'2.0.0 closing connection 4fb4d7f45d1cf-62fa5f27640sm981909a12.39 - gsmtp')

# %%
#for official email id 
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# Email Credentials
EMAIL = "cm_kitwe@dmiseu.edu.zm"
PASSWORD = "byow iijd spgp azmv"  # 16-digit app password

SMTP_SERVER = "smtp.gmail.com"
SMTP_PORT = 587

# Load Excel File
df = pd.read_excel("email.xlsx")

# Send Email Function
def send_email(to_email, subject, body):
    try:
        msg = MIMEMultipart()
        msg["From"] = EMAIL
        msg["To"] = to_email
        msg["Subject"] = subject
        msg.attach(MIMEText(body, "plain"))

        server = smtplib.SMTP(SMTP_SERVER, SMTP_PORT)
        server.starttls()
        server.login(EMAIL, PASSWORD)
        server.sendmail(EMAIL, to_email, msg.as_string())
        server.quit()

        print(f"SUCCESS: Email sent to {to_email}")
    except Exception as e:
        print(f"FAILED: {to_email} ❌ Error: {e}")

# Loop Through Excel Rows
for index, row in df.iterrows():
    send_email(row["email"], row["subject"], row["body"])
# Out:
# SUCCESS: Email sent to ajincandy5@gmail.com
# SUCCESS: Email sent to arockiaajeanconstan@gmail.com
